# %%
import pyarrow.parquet as pq
import pandas as pd
import numpy as np

# %%
campaign_program = pq.read_table(\
    '/Users/krishna/Dropbox/Data/Data/CAMPAIGN_PROGRAM/part-00000-3324c013-01e7-4da5-95cc-d16366fcfcdf-c000.snappy.parquet')
campaign_program_df = campaign_program.to_pandas()
campaign_program_df.info()
campaign_program_df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 757 entries, 0 to 756
# Data columns (total 31 columns):
# PROGRAM_ID                757 non-null int32
# SUBCATEGORY_ID            757 non-null int32
# PROGRAM_SOURCE_ID         757 non-null int32
# PROGRAM_AIRING_TYPE_ID    35 non-null float64
# CATEGORY_ID               757 non-null int32
# CAPTION_ID                712 non-null float64
# PROGRAM_COLOR_TYPE_ID     757 non-null int32
# MASTER_TITLE              757 non-null object
# RELEASE_YEAR              748 non-null object
# EPISODE_TITLE             651 non-null object
# EPISODE_NUMBER            575 non-null object
# STEREO_ENABLED_YN         757 non-null object
# STAR_RATING               11 non-null object
# SERIES_YN                 757 non-null object
# RATING_ID_TV_US           757 non-null int32
# RATING_ID_MOVIE_US        70 non-null float64
# SERIES_MASTER_YN          757 non-null object
# PARENT_PROGRAM_ID         654 non-null float64
# ...

# %%
program = pq.read_table(\
    '/Users/krishna/Dropbox/Data/Data/Program/Parquet/part-00000-17ccaa90-2d2e-4467-8920-56d97a96c4b8-c000.snappy.parquet')
program_df = program.to_pandas()
program_df.replace("NULL", np.nan,inplace=True)
program_df.info()
program_df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 819743 entries, 0 to 819742
# Data columns (total 30 columns):
# PROGRAM_ID                819743 non-null object
# SUBCATEGORY_ID            567164 non-null object
# PROGRAM_SOURCE_ID         817843 non-null object
# PROGRAM_AIRING_TYPE_ID    46295 non-null object
# CATEGORY_ID               591345 non-null object
# CAPTION_ID                319473 non-null object
# PROGRAM_COLOR_TYPE_ID     562079 non-null object
# MASTER_TITLE              819742 non-null object
# RELEASE_YEAR              370302 non-null object
# EPISODE_TITLE             437730 non-null object
# EPISODE_NUMBER            268949 non-null object
# STEREO_ENABLED_YN         585853 non-null object
# STAR_RATING               66102 non-null object
# SERIES_YN                 569749 non-null object
# RATING_ID_TV_US           587935 non-null object
# RATING_ID_MOVIE_US        107861 non-null object
# SERIES_MASTER_YN          779513 non-null object
# ...

# %%
source = pq.read_table(\
    '/Users/krishna/Dropbox/Data/Data/LOOKUP_SOURCE/part-00000-8d625316-f152-4d07-a496-c89f39c6a69f-c000.snappy.parquet')
source_df = source.to_pandas()
source_df.head()
#Source seems to be empty
# Out:
# Empty DataFrame
# Columns: [SK_SYSTEM_ID, SK_PROVIDER_ID, SOURCE_ID, SRC_NAME, SRC_LONG_NAME, SOURCE_TYPE, NETWORK, HDTV]
# Index: []

# %%
channel_info = pq.read_table('/Users/krishna/Dropbox/Data/Data/MVSN_LOOKUP_CHANNEL_NAME/part-00000-d0fef3d8-a2e4-49d9-bee6-a07e35613c0c-c000.snappy.parquet')
channel_info_df = channel_info.to_pandas()
channel_info_df.info()
channel_info_df.sort_values("SOURCE_ID").head(20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135005 entries, 0 to 135004
# Data columns (total 7 columns):
# SK_PROVIDER_ID    135005 non-null int32
# SOURCE_ID         135005 non-null int32
# SRC_NAME          135005 non-null object
# SRC_LONG_NAME     135004 non-null object
# SOURCE_TYPE       134981 non-null object
# NETWORK           135005 non-null object
# HDTV              9258 non-null object
# dtypes: int32(2), object(5)
# memory usage: 6.2+ MB
#         SK_PROVIDER_ID  SOURCE_ID SRC_NAME  \
# 0                    1          0     NULL
# 29433                2          0   (NONE)
# 74001               16          1    5SMAX
# 40316               11          1      AMC
# 41505               12          1    MC921
# 33025               10          1     AETV
# 31438                3          1   ESPNCL
# 61068               15          1  5STRMAX
# 29434                2          1     DIAG
# 89592               18          1     HBOZ
# ...

# %%
tv_info = pq.read_table(\
    '/Users/krishna/Dropbox/Data/Data/MVSN_LOOKUP_TV_PROGRAM/part-00000-88fa3fc3-2a06-4592-a382-09265cd9bdc0-c000.snappy.parquet')
tv_info_df = tv_info.to_pandas()
print("No of programs :",tv_info_df.PROGRAM_ID.count())
tv_info_df.info()
tv_info_df.head(10)
# Out:
# No of programs : 6973
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6973 entries, 0 to 6972
# Data columns (total 2 columns):
# PROGRAM_ID      6973 non-null int32
# PROGRAM_NAME    3856 non-null object
# dtypes: int32(1), object(1)
# memory usage: 81.8+ KB
#    PROGRAM_ID                     PROGRAM_NAME
# 0           0
# 1        2998                         HLN News
# 2        8338                             None
# 3       26485                       NBA Finals
# 4       30875                     The Simpsons
# 5       34742                           Damien
# 6       43491  Academy of Country Music Awards
# 7       49438                       Broad City
# 8       57083                    Scream Queens
# 9       73576                     The Simpsons

# %%
plt_pop_hist = pq.read_table(\
    '/Users/krishna/Dropbox/Data/Data/mvsn_DM_PLATFORM_POPULATION_HISTORY/part-00000-951208bb-2da8-41a0-b9aa-f1fbe7c4c8f8-c000.snappy.parquet')
plt_pop_hist_df = plt_pop_hist.to_pandas()
plt_pop_hist_df.S_DATE = [datetime.strptime(str(x), '%Y%m%d') for x in plt_pop_hist_df.S_DATE]
plt_pop_hist_df.E_DATE = [datetime.strptime(str(x), '%Y%m%d') for x in plt_pop_hist_df.E_DATE]
plt_pop_hist_df.info()
plt_pop_hist_df.sort_values("S_DATE").head(25)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 5 columns):
# SK_PLATFORM_ID    17 non-null int32
# PLATFORM          17 non-null object
# POPULATION        17 non-null int32
# S_DATE            17 non-null datetime64[ns]
# E_DATE            17 non-null datetime64[ns]
# dtypes: datetime64[ns](2), int32(2), object(1)
# memory usage: 624.0+ bytes
#     SK_PLATFORM_ID PLATFORM  POPULATION     S_DATE     E_DATE
# 16               1   iGuide     7562357 2000-01-01 2016-02-02
# 0                1   iGuide     6856852 2016-02-03 2016-05-29
# 1                1   iGuide     6804920 2016-05-30 2016-07-31
# 2                1   iGuide     6793874 2016-08-01 2016-11-27
# 4                1   iGuide     6887422 2016-11-28 2017-02-26
# 5                1   iGuide     6887422 2017-02-27 2017-06-25
# 6                1   iGuide     6760975 2017-06-26 2017-07-30
# 7                1   iGuide     6776983 2017-07-31 2017-10-29
# ...

# %%
from datetime import datetime
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt_pop_hist_df.plot("S_DATE","POPULATION",kind='line',figsize=(10,10))

# %%
plt_pop_hist_df[plt_pop_hist_df.S_DATE>'20170101'].plot("S_DATE","POPULATION",kind='line',figsize=(10,10))

# %%
sys_pop_hist = pq.read_table(\
    '/Users/krishna/Dropbox/Data/Data/mvsn_DM_SYSTEM_POPULATION_HISTORY/part-00000-e26adff4-39bb-4f77-8d75-73eebda4c06b-c000.snappy.parquet')
sys_pop_hist_df = sys_pop_hist.to_pandas()
sys_pop_hist_df.S_DATE = [datetime.strptime(str(x), '%Y%m%d') for x in sys_pop_hist_df.S_DATE]
sys_pop_hist_df.E_DATE = [datetime.strptime(str(x), '%Y%m%d') for x in sys_pop_hist_df.E_DATE]
sys_pop_hist_df.info()
sys_pop_hist_df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 7 columns):
# SK_SYSTEM_ID       24 non-null int32
# SYSTEM             24 non-null object
# SK_PLATFORM_ID     24 non-null int32
# POPULATION         24 non-null float64
# HOUSEHOLD_RATIO    24 non-null float64
# S_DATE             24 non-null datetime64[ns]
# E_DATE             24 non-null datetime64[ns]
# dtypes: datetime64[ns](2), float64(2), int32(2), object(1)
# memory usage: 1.2+ KB
#    SK_SYSTEM_ID       SYSTEM  SK_PLATFORM_ID  POPULATION  HOUSEHOLD_RATIO  \
# 0            40   Pittsburgh               1     75558.0              2.5
# 1            40   Pittsburgh               1    127797.0              2.5
# 2            41  Sioux Falls               1     97332.0              2.5
# 3            40   Pittsburgh               1    125605.0              2.5
# 4            40   Pittsburgh               1    107585.0              2.5
# ...

# %%
sys_pop_hist_df.SYSTEM.value_counts()
# Out:
# Pittsburgh     13
# Sioux Falls    11
# Name: SYSTEM, dtype: int64

# %%
sys_pop_hist_df[sys_pop_hist_df.SK_SYSTEM_ID==40].plot("S_DATE","POPULATION",kind='line',figsize=(10,10))
sys_pop_hist_df[sys_pop_hist_df.SK_SYSTEM_ID==41].plot("S_DATE","POPULATION",kind='line',figsize=(10,10))

# %%
campaign_sep = pq.read_table(\
    '/Users/krishna/Dropbox/Data/Data/CampaignOct_Sept_IGNORE/part-00000-175d1084-06c1-41a6-9256-c22f0f395f24-c000.snappy.parquet')
campaign_sep_df = campaign_sep.to_pandas()
campaign_sep_df.info()
campaign_sep_df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234038 entries, 0 to 234037
# Data columns (total 25 columns):
# CAMPAIGN_ID             234038 non-null object
# PLATFORM                234038 non-null object
# EFFECTIVE_DATE          234038 non-null datetime64[ns]
# DESCRIPTION             234038 non-null object
# CAMPAIGN                234038 non-null object
# ADVERTISER              234038 non-null object
# FEED_TYPE               234038 non-null object
# ATX_AD_ID               234038 non-null object
# EXPIRED_DATE            234038 non-null datetime64[ns]
# PROGRAM_ID              98959 non-null float64
# SOURCE_ID               5913 non-null float64
# ORDER_START_DATE        234038 non-null datetime64[ns]
# ORDER_END_DATE          234038 non-null datetime64[ns]
# VOD_ASSET               87968 non-null object
# BRAND                   234038 non-null object
# CAMPAIGN_DESCRIPTION    234038 non-null object
# AD_TYPE_DESCRIPTION     234038 non-null object
# ...

# %%
campaign_sep_df.columns
# Out:
# Index(['CAMPAIGN_ID', 'PLATFORM', 'EFFECTIVE_DATE', 'DESCRIPTION', 'CAMPAIGN',
#        'ADVERTISER', 'FEED_TYPE', 'ATX_AD_ID', 'EXPIRED_DATE', 'PROGRAM_ID',
#        'SOURCE_ID', 'ORDER_START_DATE', 'ORDER_END_DATE', 'VOD_ASSET', 'BRAND',
#        'CAMPAIGN_DESCRIPTION', 'AD_TYPE_DESCRIPTION', 'VODAd', 'VODType',
#        'goto_designator', 'icon_id', 'MASTER_DEAL_NUMBER', 'DEAL_NUMBER',
#        'TIME_ZONE', 'REGION_ID'],
#       dtype='object')

# %%
campaign = pq.read_table(\
    '/Users/krishna/Dropbox/Data/Data/Campaign_6_Months/part-00000-9ed7b965-ae49-410d-9145-c147336f3e1a-c000.snappy.parquet')
campaign_df = campaign.to_pandas()
campaign_df.head(10)
# Out:
#   CAMPAIGN_ID PLATFORM      EFFECTIVE_DATE  \
# 0       36348   iGuide 2018-11-02 10:00:00
# 1    15663655   iGuide 2018-07-22 19:00:00
# 2    15545473   iGuide 2018-06-18 05:00:00
# 3    15590806   iGuide 2018-06-24 13:00:00
# 4    15524216   iGuide 2018-06-09 13:00:00
# 5    15719931   iGuide 2018-08-12 20:00:00
# 6      144809   iGuide 2018-12-04 16:00:00
# 7       27309   iGuide 2018-10-20 12:00:00
# 8      188529   iGuide 2018-12-23 16:00:00
# 9      110593   iGuide 2018-12-04 09:00:00
#
#                                        DESCRIPTION         CAMPAIGN  \
# 0  DirectVid - Direct to Video IGuide and Passport       AddictHope
# 1       Remind - Standard Banner with Program Link  SummerMoviesECP
# 2                           SiG - Standard i-Guide  LungCancerLegal
# 3       Remind - Standard Banner with Program Link   TheAffairS4 MT
# 4       Remind - Standard Banner with Program Link        Boxing PT
# 5       Remind - Standard Banner with Program Link  ClawsFinale ECP
# ...

# %%
tv_ratings = pd.to_numeric(program_df.RATING_ID_TV_US,errors='coerce')
tv_ratings_df=tv_ratings.value_counts().to_frame()
tv_ratings_df[tv_ratings_df.RATING_ID_TV_US!= 438714].plot()

# %%
program_df[program_df.EVENT_DATE>'2016-12-31'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64678 entries, 1763 to 819733
# Data columns (total 30 columns):
# PROGRAM_ID                64678 non-null object
# SUBCATEGORY_ID            59233 non-null object
# PROGRAM_SOURCE_ID         64678 non-null object
# PROGRAM_AIRING_TYPE_ID    2163 non-null object
# CATEGORY_ID               64678 non-null object
# CAPTION_ID                39318 non-null object
# PROGRAM_COLOR_TYPE_ID     53956 non-null object
# MASTER_TITLE              64678 non-null object
# RELEASE_YEAR              39320 non-null object
# EPISODE_TITLE             35590 non-null object
# EPISODE_NUMBER            33819 non-null object
# STEREO_ENABLED_YN         64649 non-null object
# STAR_RATING               690 non-null object
# SERIES_YN                 64612 non-null object
# RATING_ID_TV_US           64297 non-null object
# RATING_ID_MOVIE_US        5239 non-null object
# SERIES_MASTER_YN          64579 non-null object
# ...

# %%
program_df[(program_df.EVENT_DATE>'2017-12-31') & (program_df.RUNTIME > '0')].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42413 entries, 3026 to 819733
# Data columns (total 30 columns):
# PROGRAM_ID                42413 non-null object
# SUBCATEGORY_ID            39183 non-null object
# PROGRAM_SOURCE_ID         42413 non-null object
# PROGRAM_AIRING_TYPE_ID    649 non-null object
# CATEGORY_ID               42413 non-null object
# CAPTION_ID                24554 non-null object
# PROGRAM_COLOR_TYPE_ID     34020 non-null object
# MASTER_TITLE              42413 non-null object
# RELEASE_YEAR              26442 non-null object
# EPISODE_TITLE             23782 non-null object
# EPISODE_NUMBER            22923 non-null object
# STEREO_ENABLED_YN         42394 non-null object
# STAR_RATING               433 non-null object
# SERIES_YN                 42349 non-null object
# RATING_ID_TV_US           42182 non-null object
# RATING_ID_MOVIE_US        2976 non-null object
# SERIES_MASTER_YN          42335 non-null object
# ...

# %%
prgram_gt_2016_df=program_df[['MASTER_TITLE','RUNTIME','EVENT_DATE']][(program_df.EVENT_DATE>'2016-12-31') & (program_df.RUNTIME > '0')]

# %%
prgram_gt_2016_df.replace(np.nan, 0,inplace=True)
